# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/sahibbhatia/Downloads/RCB.xlsx')

# %%
df[0:12]
# Out:
#    RCB 2020            Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0       POS                PLAYER        Mat       Inns         NO       Runs
# 1         1      Devdutt Padikkal         15         15          0        473
# 2         2           Virat Kohli         15         15          4        466
# 3         3        AB de Villiers         15         14          4        454
# 4         4           Aaron Finch         12         12          0        268
# 5         5           Shivam Dube         11          9          2        129
# 6         6     Washington Sundar         15          9          3        111
# 7         7         Josh Philippe          5          5          1         78
# 8         8  Gurkeerat Mann Singh          8          5          5         71
# 9         9          Chris Morris          9          5          1         34
# 10       10         Navdeep Saini         13          3          2         27
# ...

# %%
Players = df['Unnamed: 1'][1:12]
Players
# Out:
# 1         Devdutt Padikkal
# 2              Virat Kohli
# 3           AB de Villiers
# 4              Aaron Finch
# 5              Shivam Dube
# 6        Washington Sundar
# 7            Josh Philippe
# 8     Gurkeerat Mann Singh
# 9             Chris Morris
# 10           Navdeep Saini
# 11          Mohammed Siraj
# Name: Unnamed: 1, dtype: object

# %%
Averages = df['Unnamed: 7'][1:12]
Averages
# Out:
# 1     31.53
# 2     42.36
# 3      45.4
# 4     22.33
# 5     18.42
# 6      18.5
# 7      19.5
# 8     8.875
# 9       8.5
# 10       27
# 11       17
# Name: Unnamed: 7, dtype: object

# %%
df1 = pd.DataFrame({'Name': Players,'Average':Averages})

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(25,20))
plt.bar(Players,Averages,width=0.2)
plt.tick_params(axis='x', which='major', labelsize=15)
plt.tick_params(axis='y', which='major', labelsize=20)
plt.xlabel("Players")
plt.ylabel("Averages")
plt.show()
